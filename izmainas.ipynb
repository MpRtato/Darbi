# %%
from bs4 import BeautifulSoup as BS
import requests

html=requests.get('https://www.r64vsk.lv/').text
soup=BS(html, 'lxml')

izmainas=soup.select('div.r64-events')
linijas=izmainas[0].text.splitlines()

beigas=0
kopbeigas=0
cikls=1

def izmainass():
    global linijas
    global cikls
    global beigas
    global izmsk
    
    if izmsk>1: 
        print('Izmainas({}): '.format(cikls))
        print('')
        
    else:
        print('Izmainas: ')
        print('')
    
    #Tuksumu parbaude
    while 1<2:
        if ',' not in linijas[0]:
            linijas.pop(0)
        else:
            break
    
    #izmainu paradisana
    if cikls==1:
        i=0
        
    else:
        i=beigas
        
    while daudz>i:
        if cikls==1:
            if i>0 and 'diena,' in linijas[i]:
                beigas=i
                break
                
        if len(linijas[i])==1:
            break
            
        print('#'+linijas[i])
        i=i+1
    
def kopsavilkums():
    global cikls
    global beigas
    global kopbeigas
    global linijas
    global izmsk
    
    
    if izmsk>1: 
        print('Kopsavilkums({}): '.format(cikls))
        print('')
        
    else:
        print('Kopsavilkums: ')
        print('')
    
    #Diena
    print('Diena: ')
    diensk=linijas[kopbeigas].split()
    for j in linijas[kopbeigas]:
        if j.isdigit():
            diena=diensk[0]
            diena=diena.replace(',',', ')
        
        else:
            diena=diensk[0]+' '+diensk[1] 
        
        if '-' in diena:
            diena=diena.split('-')
            diena.pop(1)
            diena=diena[0]
            
    print('#'+diena)
    print('')
    
    #Skolotājas
    print('Skolā nav: ')
    if 'sk.Makuha' in linijas[kopbeigas]:
        print('#'+'sk.Makuha')

    if 'sk.Upesleja' in linijas[kopbeigas]:
        print('#'+'sk.Upesleja')

    if 'sk.Avetisjana' in linijas[kopbeigas]:
        print('#'+'sk.Avetisjana')

    if 'sk.Bukovskis' in linijas[kopbeigas]:
        print('#'+'sk.Bukovskis')

    if 'sk.Dalbiņa' in linijas[kopbeigas]:
        print('#'+'sk.Dalbiņa')

    if 'sk.Feldmanis' in linijas[kopbeigas]:
        print('#'+'sk.Feldmanis')

    if 'sk.Skrupska' in linijas[kopbeigas]:
        print('#'+'sk.Skrupska')

    if 'sk.Šics' in linijas[kopbeigas]:
        print('#'+'sk.Šics')

    if 'sk.Zinberga' in linijas[kopbeigas]:
        print('#'+'sk.Zinberga')

    if 'sk.Zīverts' in linijas[kopbeigas]:
        print('#'+'sk.Zīverts')

    print('')
    #Stundas
    print('Stundas: ')
    if cikls==1:
        i=0
    else:
        i=kopbeigas
        
    while daudz>i:
        if cikls==1:
            if i>0 and 'diena,' in linijas[i]:
                break
        
        if '11.DIT' in linijas[i]:
            print('#'+linijas[i])
            
        i=i+1
    
    kopbeigas=beigas
    cikls=cikls+1

#izmainu skaits
izmsk=0

i=0
for j in linijas:
    if 'diena,' in linijas[i]:
        izmsk=izmsk+1
        
    i=i+1

#liniju daudzums
daudz=0
for j in linijas:
    daudz=daudz+1

#Izmainu paradisana
izmainass()
print('_____________________________________________________________________')
kopsavilkums()
print('')

if izmsk>1:
    print('=====================================================================')
    izmainass()
    print('_____________________________________________________________________')
    kopsavilkums()
    print('')

#iziesana
while 2>1:
    iziesana=0
# Out:
# Izmainas:
#
# #Pirmdiena, 21.03.2022. - nebūs sk.Kāpiņa, sk.Reimandova, sk.Laugale, sk.Makuha
# #5.b - 3.st.angļu val.pie sk.Strautmanes 7.kab.(no trešdienas)
# #5.c - 7.st.brīva
# #5.d - 2.st.angļu val.pie sk.Skangales (a) 4.kab.
# #6.b - krievu val.vietā karjeras st. 13.kab.
# #6.c - 3.st.krievu val.gr.matemātika (a) 13.kab., 5.st.angļu val.(no otrdienas)
# #7.a - 2.st.brīva
# #8.b - 6.st.fizika (a) 7.kab.
# #8.c - 4.st.ģeogrāfija (a) 14.kab.
# #8.d - 1.st.brīva, krievu val.brīva
# #9.b - matemātikas brīvas
# #9.c - 4.st. 7.kab.
# #9.d - 6.st.krievu val.gr.Latvijas vēsture (a) 13.kab.
# #10.DA - 1.,2.st.17.kab.
# #10.DIT - 1.st.22.kab., 2.,3.st.36.kab.,7.st.brīva
# #10.UZ - 1.st.19.kab., 2.,3.st.20.kab.
# #10.VISP - 2.,3.st.1.kab.
# #11.DIT - 5.st.krievu val.gr.latv.val.(a) 35.kab.
# #11.UZ - 6.st.vēsture un soc.zin.I (no otrdienas) 17.kab.
# #11.VM -7.st. krievu val.gr.sports un veselība pie sk.Feldmaņa
# _____________________________________________________________________
# Kopsavilkums:
#
# Diena:
# #Pirmdiena, 21.03.2022.
#
# Skolā nav:
# #sk.Makuha
#
# Stundas:
# #11.DIT - 5.st.krievu val.gr.latv.val.(a) 35.kab.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10380/3289015639.py in <module>
#     170 #iziesana
#     171 while 2>1:
# --> 172     iziesana=0
#
# KeyboardInterrupt:
