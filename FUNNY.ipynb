# %%
def funny(n):
    
    #rindas
    rin1=[]; rin2=[]; rin3=[]; rin4=[]; rin5=[]; rin6=[]
    rin=[rin1,rin2,rin3,rin4,rin5,rin6]
    
    #sk mainigie u.c
    #0
    null1="  [][][]  "; null2="[]    [][]"; null3="[]  []  []" ;null4="[][]    []" ;null5="[]      []" ;null6="  [][][]  "
    null=[null1,null2,null3,null4,null5,null6]
    #1
    vien1="  []      "; vien2="[][]      "; vien3="  []      "; vien4="  []      "; vien5="  []      "; vien6="[][][]    " 
    vien=[vien1,vien2,vien3,vien4,vien5,vien6]
    #2
    divi1="  [][][]  "; divi2="[]      []"; divi3="      []  "; divi4="    []    "; divi5="  []      "; divi6="[][][][][]"
    divi=[divi1,divi2,divi3,divi4,divi5,divi6]
    #3
    tris1="[][][][][]"; tris2="        []"; tris3="    [][]  "; tris4="        []"; tris5="[]      []"; tris6="  [][][]  "
    tris=[tris1,tris2,tris3,tris4,tris5,tris6]
    #4
    cetr1="      []  "; cetr2="    [][]  "; cetr3="  []  []  "; cetr4="[]    []  "; cetr5="[][][][][]"; cetr6="      []  "
    cetr=[cetr1,cetr2,cetr3,cetr4,cetr5,cetr6]
    #5
    piec1="[][][][][]"; piec2="[]        "; piec3="[][][][]  "; piec4="        []"; piec5="[]      []"; piec6="  [][][]  "
    piec=[piec1,piec2,piec3,piec4,piec5,piec6]
    #6
    sesi1="  [][][]  "; sesi2="[]        "; sesi3="[][][][]  "; sesi4="[]      []"; sesi5="[]      []"; sesi6="  [][][]  "
    sesi=[sesi1,sesi2,sesi3,sesi4,sesi5,sesi6]
    #7
    sept1="[][][][][]"; sept2="        []"; sept3="      []  "; sept4="    []    "; sept5="    []    "; sept6="    []    "
    sept=[sept1,sept2,sept3,sept4,sept5,sept6]
    #8
    asto1="  [][][]  "; asto2="[]      []"; asto3="  [][][]  "; asto4="[]      []"; asto5="[]      []"; asto6="  [][][]  "
    asto=[asto1,asto2,asto3,asto4,asto5,asto6]
    #9
    devi1="  [][][]  "; devi2="[]      []"; devi3="[]      []"; devi4="  [][][][]"; devi5="        []"; devi6="  [][][]  "
    devi=[devi1,devi2,devi3,devi4,devi5,devi6]
    #-
    minu1="          "; minu2="          "; minu3="          "; minu4="[][][][][]"; minu5="          "; minu6="          "
    minu=[minu1,minu2,minu3,minu4,minu5,minu6]
    
    
    #pati funkcija
    num=list(n)
    print(" ")
    
    i=0
    a=0
    
    c0=c1=c2=c3=c4=c5=c6=c7=c8=c9=m=0
    beig=0
    while i<=len(num)*5+(len(num)-1):
        if a>len(num)-1:
            a=0
        if num[a]=='-' and num[0]=='-':
            rin[m].append(minu[m])
            m=m+1
        if num[a]=='0':
            rin[c0].append(null[c0])
            c0=c0+1
        if num[a]=='1':
            rin[c1].append(vien[c1])
            c1=c1+1
        if num[a]=='2':
            rin[c2].append(divi[c2])
            c2=c2+1
        if num[a]=='3':
            rin[c3].append(tris[c3])
            c3=c3+1
        if num[a]=='4':
            rin[c4].append(cetr[c4])
            c4=c4+1
        if num[a]=='5':
            rin[c5].append(piec[c5])
            c5=c5+1
        if num[a]=='6':
            rin[c6].append(sesi[c6])
            c6=c6+1
        if num[a]=='7':
            rin[c7].append(sept[c7])
            c7=c7+1
        if num[a]=='8':
            rin[c8].append(asto[c8])
            c8=c8+1
        if num[a]=='9':
            rin[c9].append(devi[c9])
            c9=c9+1
        if a==len(num)-1:
            print(*rin[beig])
            beig=beig+1
        a=a+1
        i=i+1
    print(" ")
        
#galvena dala        
reset=0
while reset<1:
    check=0
    
    #iet cauri ievad numb
    inp=input("sk: ")
    funny(inp)
    
    
    #atkartosana
    while check<1:
        preset=input('velreiz? (y/n): ')
        if preset=='n' or preset=='N':
            reset=1
            check=1
        if preset=='y' or preset=='Y':
            reset=0
            check=1
        elif preset!='n' and preset!='N' and preset!='y' and preset!='Y': 
            print("nepareiza atbilde")
# Out:
# sk: 704
#
# [][][][][]   [][][]         []
#         [] []    [][]     [][]
#       []   []  []  []   []  []
#     []     [][]    [] []    []
#     []     []      [] [][][][][]
#     []       [][][]         []
#
# velreiz? (y/n): y
# sk: 407
#
#       []     [][][]   [][][][][]
#     [][]   []    [][]         []
#   []  []   []  []  []       []
# []    []   [][]    []     []
# [][][][][] []      []     []
#       []     [][][]       []
